# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
print(tf.__version__)
msg = tf.constant('TensorFlow 2.0 Hello World')
tf.print(msg)
# Out:
# 2.4.1
# TensorFlow 2.0 Hello World

# %%
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad

# %%
from tensorflow import keras
from keras import models
from keras import layers

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse, r2_score as r2
import seaborn as sns

# %%
def evaluate_preds(true_values, pred_values, save=False, vis=True):
    """Оценка качества модели и график preds vs true"""
    if vis:
        print("R2:\t" + str(np.round(r2(true_values, pred_values), 5)) + "\n" +
              "RMSE:\t" + str(np.round(np.sqrt(mse(true_values, pred_values)), 3)) + "\n" +
              "MSE:\t" + str(np.round(mse(true_values, pred_values), 3)))
        
        plt.figure(figsize=(8,8))
        
        sns.scatterplot(x=pred_values, y=true_values)
        plt.plot([0, np.max(pred_values)], [0, np.max(true_values)], linestyle='--', color='black')  # диагональ, где true_values = pred_values
        
        plt.xlabel('Predicted values')
        plt.ylabel('True values')
        plt.title('True vs Predicted values')
        
        if save == True:
            plt.savefig(REPORTS_FILE_PATH + 'report.png')
        plt.show()

    return np.round(r2(true_values, pred_values), 5), np.round(np.sqrt(mse(true_values, pred_values)), 3), np.round(mse(true_values, pred_values), 3)

# %%
X, y = load_boston(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#X_train.reshape(13,339)
X_train.shape
# Out:
# (339, 13)

# %%
y_test.shape
# Out:
# (167,)

# %% [markdown]
# # Тестовый прогон

# %%
model_test = models.Sequential()
model_test.add(layers.Dense(1024, activation='relu', input_shape=(X_train.shape[1],)))
model_test.add(layers.Dense(1024, activation='relu'))
model_test.add(layers.Dense(1))

# %%
model_test.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 1024)              14336
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 1,064,961
# Trainable params: 1,064,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_test.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['mean_absolute_error'])

hist1=model_test.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 11/11 [==============================] - 2s 3ms/step - loss: 725.0696 - mean_absolute_error: 22.6499
# Epoch 2/5
# 11/11 [==============================] - 0s 3ms/step - loss: 127.0606 - mean_absolute_error: 8.2255
# Epoch 3/5
# 11/11 [==============================] - 0s 3ms/step - loss: 83.6938 - mean_absolute_error: 7.3524
# Epoch 4/5
# 11/11 [==============================] - 0s 3ms/step - loss: 85.8321 - mean_absolute_error: 6.3248
# Epoch 5/5
# 11/11 [==============================] - 0s 3ms/step - loss: 65.2784 - mean_absolute_error: 5.7163

# %%
y_pred_test = model_test.predict(X_test)
y_pred_test.shape
# Out:
# (167, 1)

# %%
y_test.shape
# Out:
# (167,)

# %%
evaluate_preds(y_test, y_pred_test.copy().flatten() )
# Out:
# R2:	0.24352
# RMSE:	7.566
# MSE:	57.249
# (0.24352, 7.566, 57.249)

# %% [markdown]
# # Варьируем количество нейронов, слоёв и прочее

# %%
model_1 = models.Sequential()
model_1.add(layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model_1.add(layers.Dense(64, activation='relu'))
model_1.add(layers.Dense(1))

model_2 = models.Sequential()
model_2.add(layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model_2.add(layers.Dense(1))

model_3 = models.Sequential()
model_3.add(layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model_3.add(layers.Dense(64, activation='relu'))
model_3.add(layers.Dense(64, activation='relu'))
model_3.add(layers.Dense(64, activation='relu'))
model_3.add(layers.Dense(64, activation='relu'))
model_3.add(layers.Dense(1))

model_4 = models.Sequential()
model_4.add(layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(64, activation='relu'))
model_4.add(layers.Dense(1))

# %%
l = [2, 1, 5, 10]
i = 0

res_list = []

for model in [model_1, model_2, model_3, model_4]:

  res = {}

  model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['mean_absolute_error'])
  
  model.fit(X_train, y_train, epochs=5,
              verbose = False)
  y_pred_test = model.predict(X_test)

  #r2, rmse, mse = evaluate_preds(y_test, y_pred_test.flatten(), vis=False)


  res['l'] = l[i]
  i += 1
  res['r2'] = round(r2(y_test, y_pred_test.copy().flatten()),5)
  res['rmse'] = round(np.sqrt(mse(y_test, y_pred_test.copy().flatten())),5)
  res['mse'] = round(mse(y_test, y_pred_test.copy().flatten()),5)

  res_list.append(res)

# %%
from pprint import pprint

# %%
pprint(res_list)
# Out:
# [{'l': 2, 'mse': 46.89845, 'r2': 0.38029, 'rmse': 6.84824},
#  {'l': 1, 'mse': 52.51999, 'r2': 0.30601, 'rmse': 7.24707},
#  {'l': 5, 'mse': 56.71774, 'r2': 0.25054, 'rmse': 7.53112},
#  {'l': 10, 'mse': 47.93904, 'r2': 0.36654, 'rmse': 6.9238}]

# %% [markdown]
# 5 cлоев оптимальнее

# %%
res_list = []

for n in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048]:

  res = {}

  model_n = models.Sequential()
  model_n.add(layers.Dense(n, activation='relu', input_shape=(X_train.shape[1],)))
  model_n.add(layers.Dense(n, activation='relu'))
  model_n.add(layers.Dense(1))

  model_n.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['mean_absolute_error'])
  
  model_n.fit(X_train, y_train, epochs=5,
              verbose = False)
  y_pred_test = model_n.predict(X_test)

  #r2, rmse, mse = evaluate_preds(y_test, y_pred_test.flatten(), vis=False)


  res['n'] = n
  res['r2'] = round(r2(y_test, y_pred_test.copy().flatten()),5)
  res['rmse'] = round(np.sqrt(mse(y_test, y_pred_test.copy().flatten())),5)
  res['mse'] = round(mse(y_test, y_pred_test.copy().flatten()),5)

  res_list.append(res)

# %%
pprint(res_list)
# Out:
# [{'mse': 806.36053, 'n': 1, 'r2': -9.65508, 'rmse': 28.39649},
#  {'mse': 3296.76469, 'n': 2, 'r2': -42.56276, 'rmse': 57.41746},
#  {'mse': 6809.33559, 'n': 4, 'r2': -88.97714, 'rmse': 82.5187},
#  {'mse': 2129.46278, 'n': 8, 'r2': -27.13828, 'rmse': 46.1461},
#  {'mse': 183.25785, 'n': 16, 'r2': -1.42153, 'rmse': 13.53728},
#  {'mse': 87.79199, 'n': 32, 'r2': -0.16007, 'rmse': 9.36974},
#  {'mse': 69.64467, 'n': 64, 'r2': 0.07973, 'rmse': 8.34534},
#  {'mse': 53.21656, 'n': 128, 'r2': 0.29681, 'rmse': 7.29497},
#  {'mse': 54.02212, 'n': 256, 'r2': 0.28616, 'rmse': 7.34997},
#  {'mse': 59.4904, 'n': 512, 'r2': 0.21391, 'rmse': 7.713},
#  {'mse': 49.63074, 'n': 1024, 'r2': 0.34419, 'rmse': 7.04491},
#  {'mse': 67.1237, 'n': 2048, 'r2': 0.11304, 'rmse': 8.19291}]

# %% [markdown]
# 1024 нейрона - оптимальнее

# %% [markdown]
# # Типы оптимизаторов

# %%
res_list = []

for opt in ['adam', 'RMSprop', 'Ftrl', 'Nadam', 'Adamax']:

  res = {}

  model_o = models.Sequential()
  model_o.add(layers.Dense(1024, activation='relu', input_shape=(X_train.shape[1],)))
  model_o.add(layers.Dense(1024, activation='relu'))
  model_o.add(layers.Dense(1))

  model_o.compile(optimizer=opt,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['mean_absolute_error'])
  
  model_o.fit(X_train, y_train, epochs=5,
              verbose = False)
  y_pred_test = model_o.predict(X_test)

  #r2, rmse, mse = evaluate_preds(y_test, y_pred_test.flatten(), vis=False)
  #print(y_pred_test)

  res['o'] = opt
  res['r2'] = round(r2(y_test, y_pred_test.copy().flatten()),5)
  res['rmse'] = round(np.sqrt(mse(y_test, y_pred_test.copy().flatten())),5)
  res['mse'] = round(mse(y_test, y_pred_test.copy().flatten()),5)

  res_list.append(res)

# %%
pprint(res_list)
# Out:
# [{'mse': 49.28974, 'o': 'adam', 'r2': 0.3487, 'rmse': 7.02067},
#  {'mse': 293.86982, 'o': 'RMSprop', 'r2': -2.88313, 'rmse': 17.14263},
#  {'mse': 55.38958, 'o': 'Ftrl', 'r2': 0.26809, 'rmse': 7.44242},
#  {'mse': 57.32117, 'o': 'Nadam', 'r2': 0.24257, 'rmse': 7.57107},
#  {'mse': 62.62362, 'o': 'Adamax', 'r2': 0.1725, 'rmse': 7.91351}]

# %% [markdown]
# 'adam' - лучше

# %% [markdown]
# # Большой тест всего со всем

# %%
res_list = []

for opt in ['adam', 'RMSprop', 'Ftrl', 'Nadam', 'Adamax']:
  for n in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048]:
    for metrics in ['mean_absolute_error', 'mean_squared_error']:
      for loss in [tf.keras.losses.MeanSquaredError(), tf.keras.losses.MeanAbsoluteError()]:
        model_1 = models.Sequential()
        model_1.add(layers.Dense(n, activation='relu', input_shape=(X_train.shape[1],)))
        model_1.add(layers.Dense(n, activation='relu'))
        model_1.add(layers.Dense(1))

        model_2 = models.Sequential()
        model_2.add(layers.Dense(n, activation='relu', input_shape=(X_train.shape[1],)))
        model_2.add(layers.Dense(1))

        model_3 = models.Sequential()
        model_3.add(layers.Dense(n, activation='relu', input_shape=(X_train.shape[1],)))
        model_3.add(layers.Dense(n, activation='relu'))
        model_3.add(layers.Dense(n, activation='relu'))
        model_3.add(layers.Dense(n, activation='relu'))
        model_3.add(layers.Dense(n, activation='relu'))
        model_3.add(layers.Dense(1))

        model_4 = models.Sequential()
        model_4.add(layers.Dense(n, activation='relu', input_shape=(X_train.shape[1],)))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(n, activation='relu'))
        model_4.add(layers.Dense(1))

        l = [2, 1, 5, 10]
        i = 0

        for model in [model_1, model_2, model_3, model_4]:

          res = {}

          model.compile(optimizer='adam',
                      loss=loss,
                      metrics=metrics)
          
          model.fit(X_train, y_train, epochs=5,
                      verbose = False)
          y_pred_test = model.predict(X_test)

          #r2, rmse, mse = evaluate_preds(y_test, y_pred_test.flatten(), vis=False)


          res['l'] = l[i]
          res['n'] = n
          res['opt'] = opt
          res['metrics'] = metrics
          res['loss'] = loss
          i += 1
          res['r2'] = round(r2(y_test, y_pred_test.copy().flatten()),5)
          res['rmse'] = round(np.sqrt(mse(y_test, y_pred_test.copy().flatten())),5)
          res['mse'] = round(mse(y_test, y_pred_test.copy().flatten()),5)

          print(res)

          res_list.append(res)
# Out:
# {'l': 2, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbd30>, 'r2': -6.15868, 'rmse': 23.2757, 'mse': 541.75827}
# {'l': 1, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbd30>, 'r2': -0.3158, 'rmse': 9.97888, 'mse': 99.57799}
# {'l': 5, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbd30>, 'r2': -6.15869, 'rmse': 23.27571, 'mse': 541.75864}
# {'l': 10, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbd30>, 'r2': -6.15868, 'rmse': 23.27571, 'mse': 541.75848}
# {'l': 2, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b783bbd68>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 1, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b783bbd68>, 'r2': -30.747, 'rmse': 49.01597, 'mse': 2402.56545}
# {'l': 5, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b783bbd68>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 1, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b783bbd68>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbda0>, 'r2': -6.15867, 'rmse': 23.27568, 'mse': 541.75722}
# {'l': 1, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbda0>, 'r2': -49.66925, 'rmse': 61.92393, 'mse': 3834.57323}
# {'l': 5, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbda0>, 'r2': -6.15862, 'rmse': 23.2756, 'mse': 541.75366}
# {'l': 10, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783bbda0>, 'r2': -6.15863, 'rmse': 23.27561, 'mse': 541.75424}
# {'l': 2, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b782fc898>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 1, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b782fc898>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 5, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b782fc898>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 1, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b782fc898>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a55ba8>, 'r2': -0.02655, 'rmse': 8.81408, 'mse': 77.68802}
# {'l': 1, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a55ba8>, 'r2': -22.15857, 'rmse': 41.86414, 'mse': 1752.60635}
# {'l': 5, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a55ba8>, 'r2': -6.38547, 'rmse': 23.64152, 'mse': 558.9217}
# {'l': 10, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a55ba8>, 'r2': -6.15869, 'rmse': 23.27571, 'mse': 541.75865}
# {'l': 2, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd008d0>, 'r2': -1311.89293, 'rmse': 315.21069, 'mse': 99357.77864}
# {'l': 1, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd008d0>, 'r2': -179.35689, 'rmse': 116.82954, 'mse': 13649.1403}
# {'l': 5, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd008d0>, 'r2': -0.62681, 'rmse': 11.09571, 'mse': 123.11467}
# {'l': 10, 'n': 2, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd008d0>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a03ebe0>, 'r2': -6.15867, 'rmse': 23.27568, 'mse': 541.75722}
# {'l': 1, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a03ebe0>, 'r2': -8.6306, 'rmse': 26.99684, 'mse': 728.82914}
# {'l': 5, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a03ebe0>, 'r2': -8.93576, 'rmse': 27.42122, 'mse': 751.92348}
# {'l': 10, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a03ebe0>, 'r2': -6.15863, 'rmse': 23.27562, 'mse': 541.75459}
# {'l': 2, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80423828>, 'r2': -202.80228, 'rmse': 124.19119, 'mse': 15423.45235}
# {'l': 1, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80423828>, 'r2': -48.95855, 'rmse': 61.48812, 'mse': 3780.78835}
# {'l': 5, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80423828>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 2, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80423828>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a133a20>, 'r2': -21.46531, 'rmse': 41.23276, 'mse': 1700.14086}
# {'l': 1, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a133a20>, 'r2': -870.87419, 'rmse': 256.86989, 'mse': 65982.13838}
# {'l': 5, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a133a20>, 'r2': -5.78591, 'rmse': 22.66158, 'mse': 513.54736}
# {'l': 10, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a133a20>, 'r2': -1.7305, 'rmse': 14.37498, 'mse': 206.64019}
# {'l': 2, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7834c5c0>, 'r2': -55.43337, 'rmse': 65.35131, 'mse': 4270.79354}
# {'l': 1, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7834c5c0>, 'r2': -38.61593, 'rmse': 54.75468, 'mse': 2998.07478}
# {'l': 5, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7834c5c0>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 4, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7834c5c0>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c64ebe0>, 'r2': -43.10032, 'rmse': 57.77063, 'mse': 3337.44614}
# {'l': 1, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c64ebe0>, 'r2': -2065.96561, 'rmse': 395.50585, 'mse': 156424.87407}
# {'l': 5, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c64ebe0>, 'r2': -5.09531, 'rmse': 21.47752, 'mse': 461.28389}
# {'l': 10, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c64ebe0>, 'r2': -6.15868, 'rmse': 23.2757, 'mse': 541.75836}
# {'l': 2, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86066fd0>, 'r2': -1.33291, 'rmse': 13.28726, 'mse': 176.55123}
# {'l': 1, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86066fd0>, 'r2': -611.61089, 'rmse': 215.31716, 'mse': 46361.47869}
# {'l': 5, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86066fd0>, 'r2': -1.97113, 'rmse': 14.99501, 'mse': 224.85042}
# {'l': 10, 'n': 4, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86066fd0>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801b2cc0>, 'r2': 0.17656, 'rmse': 7.89408, 'mse': 62.31653}
# {'l': 1, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801b2cc0>, 'r2': -61.15454, 'rmse': 68.58398, 'mse': 4703.76253}
# {'l': 5, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801b2cc0>, 'r2': -4.76235, 'rmse': 20.88268, 'mse': 436.08621}
# {'l': 10, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801b2cc0>, 'r2': -2.70966, 'rmse': 16.75534, 'mse': 280.74139}
# {'l': 2, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b788aaa58>, 'r2': -58.00768, 'rmse': 66.82524, 'mse': 4465.61283}
# {'l': 1, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b788aaa58>, 'r2': -87.34014, 'rmse': 81.7646, 'mse': 6685.45019}
# {'l': 5, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b788aaa58>, 'r2': -1.21166, 'rmse': 12.93735, 'mse': 167.3751}
# {'l': 10, 'n': 8, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b788aaa58>, 'r2': -6.11092, 'rmse': 23.19792, 'mse': 538.14346}
# {'l': 2, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b802888d0>, 'r2': -0.46502, 'rmse': 10.52952, 'mse': 110.87088}
# {'l': 1, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b802888d0>, 'r2': -184.64374, 'rmse': 118.5295, 'mse': 14049.24165}
# {'l': 5, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b802888d0>, 'r2': -184.91003, 'rmse': 118.61448, 'mse': 14069.3941}
# {'l': 10, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b802888d0>, 'r2': -6.10808, 'rmse': 23.1933, 'mse': 537.9291}
# {'l': 2, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c60bd68>, 'r2': -2.86946, 'rmse': 17.11241, 'mse': 292.83464}
# {'l': 1, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c60bd68>, 'r2': -2.93259, 'rmse': 17.25145, 'mse': 297.61261}
# {'l': 5, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c60bd68>, 'r2': -5.92918, 'rmse': 22.89956, 'mse': 524.3899}
# {'l': 10, 'n': 8, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c60bd68>, 'r2': 0.19758, 'rmse': 7.79268, 'mse': 60.72591}
# {'l': 2, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5beedf19b0>, 'r2': -1.5949, 'rmse': 14.01349, 'mse': 196.37782}
# {'l': 1, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5beedf19b0>, 'r2': -225.56648, 'rmse': 130.94355, 'mse': 17146.21293}
# {'l': 5, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5beedf19b0>, 'r2': 0.01465, 'rmse': 8.6354, 'mse': 74.57014}
# {'l': 10, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5beedf19b0>, 'r2': 0.17127, 'rmse': 7.9194, 'mse': 62.71695}
# {'l': 2, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805dc208>, 'r2': 0.0222, 'rmse': 8.60224, 'mse': 73.9986}
# {'l': 1, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805dc208>, 'r2': -13.92895, 'rmse': 33.61251, 'mse': 1129.80078}
# {'l': 5, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805dc208>, 'r2': 0.30001, 'rmse': 7.27835, 'mse': 52.97435}
# {'l': 10, 'n': 16, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805dc208>, 'r2': -0.01439, 'rmse': 8.76171, 'mse': 76.76751}
# {'l': 2, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8019f9b0>, 'r2': -4.17585, 'rmse': 19.79143, 'mse': 391.70074}
# {'l': 1, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8019f9b0>, 'r2': -31.87307, 'rmse': 49.8777, 'mse': 2487.78466}
# {'l': 5, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8019f9b0>, 'r2': 0.27016, 'rmse': 7.43192, 'mse': 55.23351}
# {'l': 10, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8019f9b0>, 'r2': -0.0322, 'rmse': 8.83829, 'mse': 78.1153}
# {'l': 2, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b785da780>, 'r2': -4.10176, 'rmse': 19.64926, 'mse': 386.09358}
# {'l': 1, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b785da780>, 'r2': -1.85915, 'rmse': 14.70972, 'mse': 216.37597}
# {'l': 5, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b785da780>, 'r2': 0.38664, 'rmse': 6.8131, 'mse': 46.41832}
# {'l': 10, 'n': 16, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b785da780>, 'r2': 0.07533, 'rmse': 8.36524, 'mse': 69.9773}
# {'l': 2, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b817b8908>, 'r2': 0.07718, 'rmse': 8.35689, 'mse': 69.83768}
# {'l': 1, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b817b8908>, 'r2': -7.26745, 'rmse': 25.01336, 'mse': 625.66829}
# {'l': 5, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b817b8908>, 'r2': 0.34649, 'rmse': 7.03253, 'mse': 49.45654}
# {'l': 10, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b817b8908>, 'r2': 0.22003, 'rmse': 7.68291, 'mse': 59.02709}
# {'l': 2, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78860438>, 'r2': 0.35293, 'rmse': 6.99782, 'mse': 48.96946}
# {'l': 1, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78860438>, 'r2': -23.54912, 'rmse': 43.10268, 'mse': 1857.8407}
# {'l': 5, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78860438>, 'r2': 0.35044, 'rmse': 7.01123, 'mse': 49.1574}
# {'l': 10, 'n': 32, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78860438>, 'r2': 0.081, 'rmse': 8.3396, 'mse': 69.54889}
# {'l': 2, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b784cdd30>, 'r2': 0.27934, 'rmse': 7.38499, 'mse': 54.53813}
# {'l': 1, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b784cdd30>, 'r2': -2.32532, 'rmse': 15.86364, 'mse': 251.65494}
# {'l': 5, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b784cdd30>, 'r2': 0.17718, 'rmse': 7.89113, 'mse': 62.26991}
# {'l': 10, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b784cdd30>, 'r2': 0.12432, 'rmse': 8.14066, 'mse': 66.27035}
# {'l': 2, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80195ef0>, 'r2': 0.1001, 'rmse': 8.25248, 'mse': 68.10342}
# {'l': 1, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80195ef0>, 'r2': -16.63769, 'rmse': 36.53483, 'mse': 1334.79397}
# {'l': 5, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80195ef0>, 'r2': 0.3671, 'rmse': 6.92075, 'mse': 47.89681}
# {'l': 10, 'n': 32, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80195ef0>, 'r2': 0.24105, 'rmse': 7.57868, 'mse': 57.43633}
# {'l': 2, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b59255f98>, 'r2': 0.19225, 'rmse': 7.81851, 'mse': 61.12908}
# {'l': 1, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b59255f98>, 'r2': -3.73124, 'rmse': 18.9223, 'mse': 358.0534}
# {'l': 5, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b59255f98>, 'r2': 0.30368, 'rmse': 7.25923, 'mse': 52.69646}
# {'l': 10, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b59255f98>, 'r2': 0.34871, 'rmse': 7.0206, 'mse': 49.28889}
# {'l': 2, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616e518>, 'r2': 0.45501, 'rmse': 6.42215, 'mse': 41.24406}
# {'l': 1, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616e518>, 'r2': 0.06408, 'rmse': 8.41599, 'mse': 70.82884}
# {'l': 5, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616e518>, 'r2': 0.30987, 'rmse': 7.2269, 'mse': 52.22811}
# {'l': 10, 'n': 64, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616e518>, 'r2': 0.34063, 'rmse': 7.06401, 'mse': 49.90026}
# {'l': 2, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a4f828>, 'r2': 0.04453, 'rmse': 8.50344, 'mse': 72.30848}
# {'l': 1, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a4f828>, 'r2': -2.73865, 'rmse': 16.82068, 'mse': 282.93522}
# {'l': 5, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a4f828>, 'r2': 0.29293, 'rmse': 7.31505, 'mse': 53.50996}
# {'l': 10, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b73a4f828>, 'r2': 0.26515, 'rmse': 7.45739, 'mse': 55.61267}
# {'l': 2, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b801ea7b8>, 'r2': 0.32028, 'rmse': 7.17216, 'mse': 51.43984}
# {'l': 1, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b801ea7b8>, 'r2': -0.12836, 'rmse': 9.2408, 'mse': 85.3924}
# {'l': 5, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b801ea7b8>, 'r2': 0.28979, 'rmse': 7.33125, 'mse': 53.74729}
# {'l': 10, 'n': 64, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b801ea7b8>, 'r2': 0.2507, 'rmse': 7.53036, 'mse': 56.70627}
# {'l': 2, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b800919e8>, 'r2': 0.33592, 'rmse': 7.08918, 'mse': 50.25649}
# {'l': 1, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b800919e8>, 'r2': 0.36637, 'rmse': 6.92474, 'mse': 47.95201}
# {'l': 5, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b800919e8>, 'r2': 0.32486, 'rmse': 7.14796, 'mse': 51.0933}
# {'l': 10, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b800919e8>, 'r2': 0.29512, 'rmse': 7.30371, 'mse': 53.34413}
# {'l': 2, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ec4e0>, 'r2': 0.45755, 'rmse': 6.40718, 'mse': 41.05195}
# {'l': 1, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ec4e0>, 'r2': 0.25178, 'rmse': 7.52492, 'mse': 56.62443}
# {'l': 5, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ec4e0>, 'r2': 0.33495, 'rmse': 7.09434, 'mse': 50.32966}
# {'l': 10, 'n': 128, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ec4e0>, 'r2': 0.24309, 'rmse': 7.56847, 'mse': 57.28178}
# {'l': 2, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c6e41d0>, 'r2': 0.32027, 'rmse': 7.17223, 'mse': 51.44087}
# {'l': 1, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c6e41d0>, 'r2': -0.20211, 'rmse': 9.53801, 'mse': 90.97362}
# {'l': 5, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c6e41d0>, 'r2': 0.0561, 'rmse': 8.4518, 'mse': 71.43287}
# {'l': 10, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5c6e41d0>, 'r2': -0.00362, 'rmse': 8.71506, 'mse': 75.95233}
# {'l': 2, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80500a90>, 'r2': 0.35586, 'rmse': 6.98197, 'mse': 48.74785}
# {'l': 1, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80500a90>, 'r2': 0.37287, 'rmse': 6.88915, 'mse': 47.46044}
# {'l': 5, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80500a90>, 'r2': 0.34323, 'rmse': 7.05004, 'mse': 49.70309}
# {'l': 10, 'n': 128, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80500a90>, 'r2': 0.33771, 'rmse': 7.0796, 'mse': 50.12076}
# {'l': 2, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8780>, 'r2': 0.25831, 'rmse': 7.49199, 'mse': 56.12988}
# {'l': 1, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8780>, 'r2': 0.41623, 'rmse': 6.64669, 'mse': 44.1785}
# {'l': 5, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8780>, 'r2': 0.2448, 'rmse': 7.55993, 'mse': 57.15262}
# {'l': 10, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8780>, 'r2': 0.36449, 'rmse': 6.93501, 'mse': 48.09434}
# {'l': 2, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5b3f8860>, 'r2': 0.30079, 'rmse': 7.27427, 'mse': 52.915}
# {'l': 1, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5b3f8860>, 'r2': 0.31868, 'rmse': 7.18062, 'mse': 51.56131}
# {'l': 5, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5b3f8860>, 'r2': 0.33705, 'rmse': 7.08317, 'mse': 50.17134}
# {'l': 10, 'n': 256, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5b3f8860>, 'r2': 0.19696, 'rmse': 7.79569, 'mse': 60.77272}
# {'l': 2, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8668>, 'r2': 0.04933, 'rmse': 8.48204, 'mse': 71.94493}
# {'l': 1, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8668>, 'r2': 0.29944, 'rmse': 7.28129, 'mse': 53.01713}
# {'l': 5, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8668>, 'r2': 0.24905, 'rmse': 7.53861, 'mse': 56.83058}
# {'l': 10, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b3f8668>, 'r2': 0.31709, 'rmse': 7.18898, 'mse': 51.68138}
# {'l': 2, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86117898>, 'r2': 0.15392, 'rmse': 8.00188, 'mse': 64.0301}
# {'l': 1, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86117898>, 'r2': 0.13013, 'rmse': 8.11359, 'mse': 65.83027}
# {'l': 5, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86117898>, 'r2': 0.34734, 'rmse': 7.02798, 'mse': 49.39255}
# {'l': 10, 'n': 256, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b86117898>, 'r2': 0.02006, 'rmse': 8.61166, 'mse': 74.16071}
# {'l': 2, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b780b6048>, 'r2': 0.38839, 'rmse': 6.80338, 'mse': 46.28605}
# {'l': 1, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b780b6048>, 'r2': 0.19574, 'rmse': 7.8016, 'mse': 60.86493}
# {'l': 5, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b780b6048>, 'r2': 0.07458, 'rmse': 8.36864, 'mse': 70.03411}
# {'l': 10, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b780b6048>, 'r2': 0.30915, 'rmse': 7.23068, 'mse': 52.28272}
# {'l': 2, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7854b080>, 'r2': 0.36953, 'rmse': 6.90744, 'mse': 47.71269}
# {'l': 1, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7854b080>, 'r2': 0.36674, 'rmse': 6.9227, 'mse': 47.92381}
# {'l': 5, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7854b080>, 'r2': 0.30521, 'rmse': 7.25123, 'mse': 52.58036}
# {'l': 10, 'n': 512, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7854b080>, 'r2': 0.34267, 'rmse': 7.05306, 'mse': 49.7457}
# {'l': 2, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8058d048>, 'r2': 0.35301, 'rmse': 6.9974, 'mse': 48.96361}
# {'l': 1, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8058d048>, 'r2': 0.36343, 'rmse': 6.94081, 'mse': 48.17479}
# {'l': 5, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8058d048>, 'r2': 0.32706, 'rmse': 7.13631, 'mse': 50.92695}
# {'l': 10, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8058d048>, 'r2': 0.25666, 'rmse': 7.50033, 'mse': 56.25494}
# {'l': 2, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c6b4908>, 'r2': 0.36021, 'rmse': 6.9583, 'mse': 48.418}
# {'l': 1, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c6b4908>, 'r2': 0.48823, 'rmse': 6.22337, 'mse': 38.7303}
# {'l': 5, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c6b4908>, 'r2': 0.35454, 'rmse': 6.98908, 'mse': 48.8473}
# {'l': 10, 'n': 512, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c6b4908>, 'r2': 0.31, 'rmse': 7.22619, 'mse': 52.21785}
# {'l': 2, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783df1d0>, 'r2': 0.32561, 'rmse': 7.14402, 'mse': 51.03703}
# {'l': 1, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783df1d0>, 'r2': 0.37272, 'rmse': 6.88999, 'mse': 47.47198}
# {'l': 5, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783df1d0>, 'r2': 0.31908, 'rmse': 7.17852, 'mse': 51.53109}
# {'l': 10, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b783df1d0>, 'r2': 0.26595, 'rmse': 7.45329, 'mse': 55.5515}
# {'l': 2, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803bfd0>, 'r2': -0.04921, 'rmse': 8.91082, 'mse': 79.40275}
# {'l': 1, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803bfd0>, 'r2': -0.3326, 'rmse': 10.04236, 'mse': 100.84894}
# {'l': 5, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803bfd0>, 'r2': 0.34266, 'rmse': 7.05312, 'mse': 49.74645}
# {'l': 10, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803bfd0>, 'r2': 0.24912, 'rmse': 7.53826, 'mse': 56.82534}
# {'l': 2, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b7838f198>, 'r2': 0.33226, 'rmse': 7.10871, 'mse': 50.53375}
# {'l': 1, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b7838f198>, 'r2': 0.43911, 'rmse': 6.51518, 'mse': 42.44761}
# {'l': 5, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b7838f198>, 'r2': 0.20914, 'rmse': 7.73635, 'mse': 59.85112}
# {'l': 10, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b7838f198>, 'r2': 0.27137, 'rmse': 7.42573, 'mse': 55.14152}
# {'l': 2, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805a0080>, 'r2': -1.75118, 'rmse': 14.42931, 'mse': 208.20496}
# {'l': 1, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805a0080>, 'r2': 0.39096, 'rmse': 6.78905, 'mse': 46.09118}
# {'l': 5, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805a0080>, 'r2': 0.29658, 'rmse': 7.29614, 'mse': 53.23363}
# {'l': 10, 'n': 1024, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b805a0080>, 'r2': 0.29867, 'rmse': 7.28528, 'mse': 53.07527}
# {'l': 2, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3a320>, 'r2': 0.21661, 'rmse': 7.69971, 'mse': 59.28549}
# {'l': 1, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3a320>, 'r2': 0.47995, 'rmse': 6.2735, 'mse': 39.35676}
# {'l': 5, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3a320>, 'r2': -0.19186, 'rmse': 9.49728, 'mse': 90.19831}
# {'l': 10, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3a320>, 'r2': 0.07143, 'rmse': 8.38289, 'mse': 70.27278}
# {'l': 2, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78605198>, 'r2': 0.32699, 'rmse': 7.13667, 'mse': 50.93212}
# {'l': 1, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78605198>, 'r2': 0.28575, 'rmse': 7.35209, 'mse': 54.05322}
# {'l': 5, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78605198>, 'r2': 0.33919, 'rmse': 7.0717, 'mse': 50.00891}
# {'l': 10, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b78605198>, 'r2': 0.33383, 'rmse': 7.10034, 'mse': 50.41481}
# {'l': 2, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8023e8d0>, 'r2': 0.28493, 'rmse': 7.3563, 'mse': 54.11515}
# {'l': 1, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8023e8d0>, 'r2': 0.44032, 'rmse': 6.5081, 'mse': 42.3554}
# {'l': 5, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8023e8d0>, 'r2': -0.04974, 'rmse': 8.91306, 'mse': 79.44263}
# {'l': 10, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8023e8d0>, 'r2': -0.00428, 'rmse': 8.71794, 'mse': 76.00239}
# {'l': 2, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80439390>, 'r2': 0.288, 'rmse': 7.34052, 'mse': 53.88324}
# {'l': 1, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80439390>, 'r2': 0.26022, 'rmse': 7.48235, 'mse': 55.98549}
# {'l': 5, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80439390>, 'r2': 0.38758, 'rmse': 6.80789, 'mse': 46.34732}
# {'l': 10, 'n': 2048, 'opt': 'adam', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b80439390>, 'r2': 0.12922, 'rmse': 8.11783, 'mse': 65.89918}
# {'l': 2, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b86233d30>, 'r2': -6.15882, 'rmse': 23.27592, 'mse': 541.7685}
# {'l': 1, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b86233d30>, 'r2': -6.32148, 'rmse': 23.53888, 'mse': 554.07897}
# {'l': 5, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b86233d30>, 'r2': -6.15867, 'rmse': 23.27569, 'mse': 541.75752}
# {'l': 10, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b86233d30>, 'r2': -6.15869, 'rmse': 23.27572, 'mse': 541.75895}
# {'l': 2, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7808c668>, 'r2': -1.6423, 'rmse': 14.1409, 'mse': 199.96502}
# {'l': 1, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7808c668>, 'r2': -15.76764, 'rmse': 35.62232, 'mse': 1268.94966}
# {'l': 5, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7808c668>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7808c668>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80246ac8>, 'r2': -6.15866, 'rmse': 23.27567, 'mse': 541.75702}
# {'l': 1, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80246ac8>, 'r2': -11.47739, 'rmse': 30.72898, 'mse': 944.26994}
# {'l': 5, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80246ac8>, 'r2': -6.15873, 'rmse': 23.27578, 'mse': 541.76187}
# {'l': 10, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80246ac8>, 'r2': -6.15861, 'rmse': 23.27559, 'mse': 541.75299}
# {'l': 2, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b72099710>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 1, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b72099710>, 'r2': -6.17479, 'rmse': 23.30187, 'mse': 542.97716}
# {'l': 5, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b72099710>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 1, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b72099710>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a223278>, 'r2': -6.16325, 'rmse': 23.28312, 'mse': 542.10374}
# {'l': 1, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a223278>, 'r2': -6.15877, 'rmse': 23.27584, 'mse': 541.7647}
# {'l': 5, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a223278>, 'r2': -6.15853, 'rmse': 23.27545, 'mse': 541.7465}
# {'l': 10, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a223278>, 'r2': -6.15864, 'rmse': 23.27563, 'mse': 541.75498}
# {'l': 2, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b861b6f60>, 'r2': -33.06095, 'rmse': 50.77087, 'mse': 2577.6817}
# {'l': 1, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b861b6f60>, 'r2': -0.22821, 'rmse': 9.64102, 'mse': 92.94925}
# {'l': 5, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b861b6f60>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b861b6f60>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b787d6128>, 'r2': -1.0071, 'rmse': 12.32455, 'mse': 151.89454}
# {'l': 1, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b787d6128>, 'r2': -2.21966, 'rmse': 15.60958, 'mse': 243.659}
# {'l': 5, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b787d6128>, 'r2': -6.15872, 'rmse': 23.27576, 'mse': 541.76115}
# {'l': 10, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b787d6128>, 'r2': -0.23033, 'rmse': 9.64932, 'mse': 93.10943}
# {'l': 2, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b787d6160>, 'r2': -41.24783, 'rmse': 56.54425, 'mse': 3197.25259}
# {'l': 1, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b787d6160>, 'r2': -4.83707, 'rmse': 21.01763, 'mse': 441.74086}
# {'l': 5, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b787d6160>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 10, 'n': 2, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b787d6160>, 'r2': -6.15858, 'rmse': 23.27555, 'mse': 541.75102}
# {'l': 2, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d7f0ac8>, 'r2': -11.29807, 'rmse': 30.50737, 'mse': 930.69985}
# {'l': 1, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d7f0ac8>, 'r2': 0.04017, 'rmse': 8.52282, 'mse': 72.63845}
# {'l': 5, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d7f0ac8>, 'r2': -1.07691, 'rmse': 12.53704, 'mse': 157.17729}
# {'l': 10, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d7f0ac8>, 'r2': -0.29002, 'rmse': 9.88062, 'mse': 97.62668}
# {'l': 2, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5920c128>, 'r2': -1.25706, 'rmse': 13.06947, 'mse': 170.81099}
# {'l': 1, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5920c128>, 'r2': -49.82505, 'rmse': 62.01906, 'mse': 3846.36425}
# {'l': 5, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5920c128>, 'r2': -28.46063, 'rmse': 47.21797, 'mse': 2229.53646}
# {'l': 10, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5920c128>, 'r2': -2.18733, 'rmse': 15.531, 'mse': 241.21204}
# {'l': 2, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a1f9ba8>, 'r2': -6.1586, 'rmse': 23.27557, 'mse': 541.75199}
# {'l': 1, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a1f9ba8>, 'r2': -1.71614, 'rmse': 14.33712, 'mse': 205.55307}
# {'l': 5, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a1f9ba8>, 'r2': -0.05658, 'rmse': 8.94206, 'mse': 79.96036}
# {'l': 10, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b6a1f9ba8>, 'r2': -6.11676, 'rmse': 23.20745, 'mse': 538.58551}
# {'l': 2, 'n': 4, 'opt': 'RMSprop', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b801eae10>, 'r2': -96.41824, 'rmse': 85.86307, 'mse': 7372.46711}
# ...
# {'l': 5, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b590bee10>, 'r2': 0.36921, 'rmse': 6.90921, 'mse': 47.73724}
# {'l': 10, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b590bee10>, 'r2': 0.33892, 'rmse': 7.07316, 'mse': 50.02958}
# {'l': 2, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ece80>, 'r2': 0.31214, 'rmse': 7.21502, 'mse': 52.05647}
# {'l': 1, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ece80>, 'r2': 0.09449, 'rmse': 8.27815, 'mse': 68.52771}
# {'l': 5, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ece80>, 'r2': 0.24179, 'rmse': 7.57497, 'mse': 57.38014}
# {'l': 10, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5c5ece80>, 'r2': 0.21874, 'rmse': 7.68924, 'mse': 59.12441}
# {'l': 2, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80276f98>, 'r2': 0.34352, 'rmse': 7.04851, 'mse': 49.68146}
# {'l': 1, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80276f98>, 'r2': 0.2799, 'rmse': 7.38216, 'mse': 54.4963}
# {'l': 5, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80276f98>, 'r2': 0.41859, 'rmse': 6.63324, 'mse': 43.99989}
# {'l': 10, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80276f98>, 'r2': 0.16234, 'rmse': 7.96198, 'mse': 63.39306}
# {'l': 2, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803b390>, 'r2': 0.26896, 'rmse': 7.43802, 'mse': 55.32417}
# {'l': 1, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803b390>, 'r2': 0.18815, 'rmse': 7.83835, 'mse': 61.43974}
# {'l': 5, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803b390>, 'r2': 0.33481, 'rmse': 7.09511, 'mse': 50.34055}
# {'l': 10, 'n': 128, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7803b390>, 'r2': 0.27003, 'rmse': 7.43257, 'mse': 55.24311}
# {'l': 2, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b408cf8>, 'r2': 0.06562, 'rmse': 8.40906, 'mse': 70.71236}
# {'l': 1, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b408cf8>, 'r2': 0.36022, 'rmse': 6.95829, 'mse': 48.41774}
# {'l': 5, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b408cf8>, 'r2': 0.19269, 'rmse': 7.8164, 'mse': 61.09606}
# {'l': 10, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5b408cf8>, 'r2': 0.22785, 'rmse': 7.64429, 'mse': 58.4352}
# {'l': 2, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3ce48>, 'r2': 0.41619, 'rmse': 6.64694, 'mse': 44.18182}
# {'l': 1, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3ce48>, 'r2': 0.22458, 'rmse': 7.66044, 'mse': 58.68234}
# {'l': 5, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3ce48>, 'r2': 0.14301, 'rmse': 8.05331, 'mse': 64.85584}
# {'l': 10, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3ce48>, 'r2': 0.35822, 'rmse': 6.96915, 'mse': 48.56907}
# {'l': 2, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80138908>, 'r2': 0.3869, 'rmse': 6.81165, 'mse': 46.39853}
# {'l': 1, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80138908>, 'r2': 0.33522, 'rmse': 7.09293, 'mse': 50.30969}
# {'l': 5, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80138908>, 'r2': 0.3463, 'rmse': 7.03358, 'mse': 49.47131}
# {'l': 10, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80138908>, 'r2': 0.30705, 'rmse': 7.24163, 'mse': 52.44126}
# {'l': 2, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a3960b8>, 'r2': -0.15723, 'rmse': 9.35826, 'mse': 87.57707}
# {'l': 1, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a3960b8>, 'r2': 0.47817, 'rmse': 6.28422, 'mse': 39.49138}
# {'l': 5, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a3960b8>, 'r2': 0.27869, 'rmse': 7.38836, 'mse': 54.58787}
# {'l': 10, 'n': 256, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a3960b8>, 'r2': -0.25997, 'rmse': 9.76485, 'mse': 95.35236}
# {'l': 2, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d747320>, 'r2': 0.26303, 'rmse': 7.46813, 'mse': 55.77293}
# {'l': 1, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d747320>, 'r2': 0.35757, 'rmse': 6.97266, 'mse': 48.61794}
# {'l': 5, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d747320>, 'r2': 0.30463, 'rmse': 7.25428, 'mse': 52.62455}
# {'l': 10, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d747320>, 'r2': 0.35379, 'rmse': 6.99315, 'mse': 48.90418}
# {'l': 2, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616ed68>, 'r2': 0.23139, 'rmse': 7.62676, 'mse': 58.16747}
# {'l': 1, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616ed68>, 'r2': 0.41637, 'rmse': 6.64592, 'mse': 44.1682}
# {'l': 5, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616ed68>, 'r2': -0.1062, 'rmse': 9.14962, 'mse': 83.71548}
# {'l': 10, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b8616ed68>, 'r2': -0.05061, 'rmse': 8.91676, 'mse': 79.50859}
# {'l': 2, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80415320>, 'r2': 0.03163, 'rmse': 8.56066, 'mse': 73.28484}
# {'l': 1, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80415320>, 'r2': 0.37017, 'rmse': 6.90397, 'mse': 47.66482}
# {'l': 5, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80415320>, 'r2': 0.28776, 'rmse': 7.34174, 'mse': 53.90118}
# {'l': 10, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b80415320>, 'r2': 0.3068, 'rmse': 7.24294, 'mse': 52.46014}
# {'l': 2, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a387b38>, 'r2': -0.93324, 'rmse': 12.09566, 'mse': 146.30487}
# {'l': 1, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a387b38>, 'r2': 0.44069, 'rmse': 6.50598, 'mse': 42.32771}
# {'l': 5, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a387b38>, 'r2': 0.37913, 'rmse': 6.85468, 'mse': 46.9866}
# {'l': 10, 'n': 512, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5a387b38>, 'r2': 0.33001, 'rmse': 7.12064, 'mse': 50.70349}
# {'l': 2, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8629a198>, 'r2': 0.18039, 'rmse': 7.87569, 'mse': 62.02656}
# {'l': 1, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8629a198>, 'r2': 0.46959, 'rmse': 6.33566, 'mse': 40.14064}
# {'l': 5, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8629a198>, 'r2': 0.1621, 'rmse': 7.96309, 'mse': 63.41074}
# {'l': 10, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b8629a198>, 'r2': 0.21977, 'rmse': 7.68419, 'mse': 59.04675}
# {'l': 2, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3a860>, 'r2': 0.06103, 'rmse': 8.4297, 'mse': 71.05987}
# {'l': 1, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3a860>, 'r2': 0.43336, 'rmse': 6.54848, 'mse': 42.88263}
# {'l': 5, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3a860>, 'r2': 0.35995, 'rmse': 6.95972, 'mse': 48.43769}
# {'l': 10, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b73a3a860>, 'r2': -0.00789, 'rmse': 8.7336, 'mse': 76.2757}
# {'l': 2, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d709c18>, 'r2': 0.02678, 'rmse': 8.58207, 'mse': 73.65195}
# {'l': 1, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d709c18>, 'r2': 0.46334, 'rmse': 6.37289, 'mse': 40.61368}
# {'l': 5, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d709c18>, 'r2': 0.22207, 'rmse': 7.67285, 'mse': 58.87262}
# {'l': 10, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5d709c18>, 'r2': 0.25484, 'rmse': 7.50949, 'mse': 56.39249}
# {'l': 2, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b58999cc0>, 'r2': 0.28948, 'rmse': 7.33287, 'mse': 53.77096}
# {'l': 1, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b58999cc0>, 'r2': 0.24519, 'rmse': 7.55796, 'mse': 57.12273}
# {'l': 5, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b58999cc0>, 'r2': 0.26393, 'rmse': 7.46358, 'mse': 55.70498}
# {'l': 10, 'n': 1024, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b58999cc0>, 'r2': 0.31129, 'rmse': 7.21944, 'mse': 52.12032}
# {'l': 2, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801a3ac8>, 'r2': 0.3124, 'rmse': 7.21363, 'mse': 52.03643}
# {'l': 1, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801a3ac8>, 'r2': 0.47761, 'rmse': 6.28761, 'mse': 39.53405}
# {'l': 5, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801a3ac8>, 'r2': 0.29855, 'rmse': 7.28593, 'mse': 53.08478}
# {'l': 10, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b801a3ac8>, 'r2': 0.29436, 'rmse': 7.30765, 'mse': 53.40181}
# {'l': 2, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd3a710>, 'r2': 0.38077, 'rmse': 6.8456, 'mse': 46.86222}
# {'l': 1, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd3a710>, 'r2': 0.48889, 'rmse': 6.21932, 'mse': 38.68}
# {'l': 5, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd3a710>, 'r2': 0.26047, 'rmse': 7.48107, 'mse': 55.96641}
# {'l': 10, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_absolute_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b5bd3a710>, 'r2': 0.19487, 'rmse': 7.80584, 'mse': 60.9312}
# {'l': 2, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3aa58>, 'r2': 0.34572, 'rmse': 7.03671, 'mse': 49.51529}
# {'l': 1, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3aa58>, 'r2': 0.20501, 'rmse': 7.75651, 'mse': 60.16342}
# {'l': 5, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3aa58>, 'r2': 0.27942, 'rmse': 7.3846, 'mse': 54.53229}
# {'l': 10, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanSquaredError object at 0x7f5b5bd3aa58>, 'r2': 0.27796, 'rmse': 7.39208, 'mse': 54.64282}
# {'l': 2, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7888a860>, 'r2': 0.33981, 'rmse': 7.06838, 'mse': 49.962}
# {'l': 1, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7888a860>, 'r2': 0.17274, 'rmse': 7.91238, 'mse': 62.60577}
# {'l': 5, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7888a860>, 'r2': 0.37532, 'rmse': 6.87569, 'mse': 47.27515}
# {'l': 10, 'n': 2048, 'opt': 'Adamax', 'metrics': 'mean_squared_error', 'loss': <tensorflow.python.keras.losses.MeanAbsoluteError object at 0x7f5b7888a860>, 'r2': 0.32631, 'rmse': 7.14029, 'mse': 50.98368}

# %%
import pandas as pd

# %%
df = pd.DataFrame(res_list)

# %%
df.sort_values(by='r2', ascending=False).head(10)
# Out:
#      l     n      opt  ...       r2     rmse       mse
# 569  1  2048     Ftrl  ...  0.53451  5.93530  35.22773
# 353  1  1024  RMSprop  ...  0.50062  6.14757  37.79262
# 749  1  1024    Nadam  ...  0.49447  6.18530  38.25794
# 381  1  2048  RMSprop  ...  0.49020  6.21137  38.58106
# 949  1  2048   Adamax  ...  0.48889  6.21932  38.68000
# 157  1   512     adam  ...  0.48823  6.22337  38.73030
# 757  1  2048    Nadam  ...  0.48562  6.23922  38.92785
# 177  1  2048     adam  ...  0.47995  6.27350  39.35676
# 909  1   256   Adamax  ...  0.47817  6.28422  39.49138
# 288  2    64  RMSprop  ...  0.47793  6.28565  39.50944
#
# [10 rows x 8 columns]
